# %% [markdown]
# git init .
#
# git remote add origin "https://github.com/anshika2006raj/Do-to-list.git"
#
# git add .
#
# git commit -m "add comment"
#
# git branch -m main
#
# git push origin main
#
#
# github ke command...

# %%
git config --global user.name "anshika2006raj"
git config --global user.email"anshika92raj@gmail.com"

# %% [markdown]
# git config --global user.name "anshika2006raj"
